# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCastrillonL/Data-Integration-Analytics/blob/main/Integracion_Dinamica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/content/sample_data/6. NBA_Data (1).xlsx"

df = pd.read_excel(path,sheet_name=0)
df.head()

XDB = df.iloc[:,1:6] #variables de interes
XDB.dropna()
XDB.head()
# Out:
#      salary  age  height  weight  games_played
# 0    947276   36      79     260           966
# 1  25000000   37      78     212          1346
# 2   4088019   39      78     220          1274
# 3   5675000   36      77     195          1100
# 4   5250000   40      83     250          1392

# %% [markdown]
# procedo con la clusterizacion estatica

# %%
XDBM  = np.max(XDB, axis=0) #maximos
XDBM

XDBm = np.min(XDB, axis=0) #minimos
XDBm

np.random.seed(42)

#semillas (serian 5 en este caso)
XC = np.zeros((5,5))

for i in range (5): #numero de montones de datos
  for j in range (5): #cada monton va a tener 5 variables
    XC[i,j] = np.random.uniform(XDBm[j],XDBM[j])

XDB = np.array(XDB)
XCd = np.zeros((5,5))
ND = np.zeros((5,1))


#clasificacion de los datos por monton

for k in range(len(XDB)):
  d = np.sum(np.abs(XC[:,:]-XDB[k,:]), axis=1) # distancia de un registro a un cluster
  fila = np.argmin(d) # numero de cluster al que pertenece un dato
  XCd[fila,]= XCd[fila,]+XDB[k,:] #sumo la info de las variables a los clusters
  ND[fila,]=ND[fila,]+1 #cuanto el numero de datos que quedaron por cada cluster

print("el numero de datos por cluster es:", ND)

XCd = XCd/ND # divido todas las variables por el numero de datos del cluster

dfxco= pd.DataFrame((XCd.astype(float)))
dfxco.columns=["salary", "age", "height", "weight", "games_played"]
dfxco.head(5)

pd.DataFrame((XDB)).corr()
# Out:
# el numero de datos por cluster es: [[50.]
#  [42.]
#  [62.]
#  [45.]
#  [50.]]
#           0         1         2         3         4
# 0  1.000000 -0.243711  0.069705  0.098346  0.066004
# 1 -0.243711  1.000000  0.005723  0.015531  0.787159
# 2  0.069705  0.005723  1.000000  0.857509 -0.022546
# 3  0.098346  0.015531  0.857509  1.000000  0.011834
# 4  0.066004  0.787159 -0.022546  0.011834  1.000000

# %% [markdown]
# Integracion dinamica

# %%
dfe = pd.read_excel(path,sheet_name=1)
dfe.head()

XDBe = np.array(dfe.iloc[:,1:6].dropna())#variables de interes

Xco = np.copy(XCd) #clusters estaticos/iniciales
NDe = np.zeros((5,1)) #numero de datos por cluster

for k in range(len(XDBe)):
  de = np.sqrt(np.sum((Xco[:,:]-XDBe[k,:])**2, axis=1)) #voy sumando la informacion de las varuables a los clusters
  fila = np.argmin(de)
  Xco[fila,]= (Xco[fila,]+XDBe[k,:])/2 #sumo la info de las variables a los clusters

  NDe[fila,]=NDe[fila,]+1

print("el numero de datos integrados por cluster es:\n", NDe )
print("la estructura de los clusters antes es:\n", XCd )
#print("la estructura de los clusters despues es:\n", X )
# Out:
# el numero de datos integrados por cluster es:
#  [[  0.]
#  [ 46.]
#  [133.]
#  [ 15.]
#  [  2.]]
# la estructura de los clusters antes es:
#  [[9.54107436e+06 2.89200000e+01 7.91400000e+01 2.23080000e+02
#   5.89720000e+02]
#  [3.33758560e+06 3.03333333e+01 7.89047619e+01 2.25214286e+02
#   5.58214286e+02]
#  [1.02045379e+06 3.07419355e+01 7.90967742e+01 2.21919355e+02
#   5.46580645e+02]
#  [5.57348180e+06 2.99555556e+01 7.89111111e+01 2.21377778e+02
#   5.65000000e+02]
#  [1.66972432e+07 2.81400000e+01 7.98200000e+01 2.29320000e+02
#   5.72300000e+02]]
